# %% [markdown]
# ## Import the necessary packages

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import pyplot
from matplotlib import rcParams
# %matplotlib inline
from scipy import stats
from collections import Counter
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
def parser(x):
    return datetime.strptime(x,'%d-%m-%y').date()

# %% [markdown]
# ## Load the dataset of object detection

# %%
data=pd.read_csv("C:\\Users\Ishan.Borkar\Downloads\Detection_Results.csv",header=0)
data.head()
# Out:
#        image                                         image_path  xmin  ymin  \
# 0  00228.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   734   266
# 1  00228.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   709   253
# 2  00228.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   301   262
# 3  00228.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   416   122
# 4  00231.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   324   229
#
#    xmax  ymax  label  confidence  x_size  y_size
# 0   800   342      4    0.383168     964     536
# 1   823   369      4    0.665065     964     536
# 2   395   358      4    0.669802     964     536
# 3   659   362      3    0.520829     964     536
# 4   426   387      4    0.610569     640     480

# %%
data.sort_values(by=['image'], inplace=True)

# %%
data.count()
# Out:
# image         135
# image_path    135
# xmin          135
# ymin          135
# xmax          135
# ymax          135
# label         135
# confidence    135
# x_size        135
# y_size        135
# dtype: int64

# %% [markdown]
# ## 1) Phase 1: 101 Training and 10 Testing Images

# %%
data1=data.loc[data['image'].str.contains("00",case=False)]
data1.head()
# Out:
#         image                                         image_path  xmin  ymin  \
# 29  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   394   193
# 31  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   414   166
# 32  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   235   193
# 33  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   375   104
# 38  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   128   130
#
#     xmax  ymax  label  confidence  x_size  y_size
# 29   465   249      4    0.701575     465     342
# 31   464   279      4    0.934611     465     342
# 32   329   313      4    0.983308     465     342
# 33   427   218      3    0.581255     465     342
# 38   279   174      0    0.620873     465     342

# %%
data1.count()
# Out:
# image         66
# image_path    66
# xmin          66
# ymin          66
# xmax          66
# ymax          66
# label         66
# confidence    66
# x_size        66
# y_size        66
# dtype: int64

# %%
A=data1['confidence'].mean()
A
# Out:
# 0.6603105072722291

# %% [markdown]
# ## Average confidence score of 0: Light

# %%
data1_0=data1[data1['label'] == 0]
data1_0
# Out:
#         image                                         image_path  xmin  ymin  \
# 38  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   128   130
# 37  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    69   132
# 42  00226.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    47    78
# 41  00226.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   170    76
# 65  00227.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   182   213
# 20  00229.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    10    65
# 59  00230.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...  2563  1358
# 8   00231.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   198   177
# 51  00232.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    19   222
# 52  00232.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   219   200
# 15  00233.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   758   558
# ...

# %%
a1=data1_0['confidence'].mean()
a1
# Out:
# 0.5914439335465431

# %% [markdown]
# ## Average confidence score of 1: Glass

# %%
data1_1=data1[data1['label'] == 1]
data1_1
# Out:
#         image                                         image_path  xmin  ymin  \
# 36  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    38    64
# 40  00226.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    58    17
# 39  00226.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   199    28
# 64  00227.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   254    69
# 58  00230.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...  1656   556
# 7   00231.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   318   101
# 50  00232.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   140   115
# 14  00233.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   707   123
# 27  00234.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   513   376
#
#     xmax  ymax  label  confidence  x_size  y_size
# 36   206   130      1    0.708930     465     342
# 40   188    55      1    0.889396     259     194
# ...

# %%
a2=data1_1['confidence'].mean()
a2
# Out:
# 0.7456397248639001

# %% [markdown]
# ## Average confidence score of 2: SideGlass

# %%
data1_2=data1[data1['label'] == 2]
data1_2
# Out:
#         image                                         image_path  xmin  ymin  \
# 35  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   406   116
# 63  00227.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   469   124
# 57  00230.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...  1210   792
# 56  00230.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...  1259   920
# 49  00232.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   386   152
# 12  00233.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   622   263
# 13  00233.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...  1300   302
# 25  00234.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   380   448
# 26  00234.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   369   419
#
#     xmax  ymax  label  confidence  x_size  y_size
# 35   430   149      2    0.378376     465     342
# 63   531   170      2    0.655118     640     480
# ...

# %%
a3=data1_2['confidence'].mean()
a3
# Out:
# 0.49093592829174465

# %% [markdown]
# ## Average confidence score of 3: Door

# %%
data1_3=data1[data1['label'] == 3]
data1_3
# Out:
#         image                                         image_path  xmin  ymin  \
# 33  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   375   104
# 34  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   327    60
# 62  00227.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   455    63
# 3   00228.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   416   122
# 18  00229.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    73    46
# 19  00229.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   104    52
# 55  00230.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   682   355
# 6   00231.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   479   124
# 48  00232.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   381   118
# 47  00232.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   437   128
# 46  00232.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   405    85
# ...

# %%
a4=data1_3['confidence'].mean()
a4
# Out:
# 0.638260577406202

# %% [markdown]
# ## Average confidence score of 4: Wheel

# %%
data1_4=data1[data1['label'] == 4]
data1_4
# Out:
#         image                                         image_path  xmin  ymin  \
# 29  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   394   193
# 31  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   414   166
# 32  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   235   193
# 30  00225.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    40   254
# 60  00227.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   335   240
# 61  00227.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   553   163
# 2   00228.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   301   262
# 1   00228.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   709   253
# 0   00228.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   734   266
# 16  00229.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    35    97
# 17  00229.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   187    96
# ...

# %%
a5=data1_4['confidence'].mean()
a5
# Out:
# 0.7462880597873167

# %% [markdown]
# ## 2) Phase 2: 2 New images training and testing

# %%
data2=data.loc[data['image'].str.contains("my",case=False)]
data2.head()
# Out:
#          image                                         image_path  xmin  ymin  \
# 70  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   375    95
# 71  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   383   151
# 69  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   425   133
# 68  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   370   154
# 66  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   311   218
#
#     xmax  ymax  label  confidence  x_size  y_size
# 70   437   315      3    0.831621     640     420
# 71   412   186      2    0.432605     640     420
# 69   490   265      3    0.764939     640     420
# 68   480   257      3    0.406694     640     420
# 66   367   319      4    0.908945     640     420

# %%
data2.count()
# Out:
# image         14
# image_path    14
# xmin          14
# ymin          14
# xmax          14
# ymax          14
# label         14
# confidence    14
# x_size        14
# y_size        14
# dtype: int64

# %%
B=data2['confidence'].mean()
B
# Out:
# 0.6691271066665649

# %% [markdown]
# ### Average confidence score of 0: Light

# %%
data2_0=data2[data2['label'] == 0]
data2_0
# Out:
#           image                                         image_path  xmin  \
# 79  mydata2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   142
# 78  mydata2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   520
#
#     ymin  xmax  ymax  label  confidence  x_size  y_size
# 79   233   226   352      0    0.695437     728     546
# 78   221   607   398      0    0.541733     728     546

# %%
b1=data2_0['confidence'].mean()
b1
# Out:
# 0.6185853779315948

# %% [markdown]
# ### Average confidence score of 1: Glass

# %%
data2_1=data2[data2['label'] == 1]
data2_1
# Out:
#           image                                         image_path  xmin  \
# 73   mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   198
# 77  mydata2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   209
#
#     ymin  xmax  ymax  label  confidence  x_size  y_size
# 73   126   412   186      1    0.857558     640     420
# 77    51   532   192      1    0.888366     728     546

# %%
b2=data2_1['confidence'].mean()
b2
# Out:
# 0.8729615807533264

# %% [markdown]
# ### Average confidence score of 2: SideGlass

# %%
data2_2=data2[data2['label'] == 2]
data2_2
# Out:
#           image                                         image_path  xmin  \
# 71   mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   383
# 72   mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   374
# 74  mydata2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   567
# 75  mydata2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   177
# 76  mydata2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   544
#
#     ymin  xmax  ymax  label  confidence  x_size  y_size
# 71   151   412   186      2    0.432605     640     420
# 72   161   423   195      2    0.794570     640     420
# 74   121   591   190      2    0.303055     728     546
# 75   131   220   177      2    0.311386     728     546
# 76   134   609   179      2    0.688521     728     546

# %%
b3=data2_2['confidence'].mean()
b3
# Out:
# 0.5060275733470917

# %% [markdown]
# ### Average confidence score of 3: Door

# %%
data2_3=data2[data2['label'] == 3]
data2_3
# Out:
#          image                                         image_path  xmin  ymin  \
# 70  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   375    95
# 69  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   425   133
# 68  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   370   154
#
#     xmax  ymax  label  confidence  x_size  y_size
# 70   437   315      3    0.831621     640     420
# 69   490   265      3    0.764939     640     420
# 68   480   257      3    0.406694     640     420

# %%
b4=data2_3['confidence'].mean()
b4
# Out:
# 0.6677510639031728

# %% [markdown]
# ### Average confidence score of 4: Wheel

# %%
data2_4=data2[data2['label'] == 4]
data2_4
# Out:
#          image                                         image_path  xmin  ymin  \
# 66  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   311   218
# 67  mydata.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   478   208
#
#     xmax  ymax  label  confidence  x_size  y_size
# 66   367   319      4    0.908945     640     420
# 67   524   282      4    0.942349     640     420

# %%
b5=data2_4['confidence'].mean()
b5
# Out:
# 0.9256472587585449

# %% [markdown]
# ## 3) Phase 3: 10 Unseen images

# %%
data3=data.loc[data['image'].str.contains("Unseen",case=False)]
data3.head()
# Out:
#            image                                         image_path  xmin  \
# 106  Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   101
# 103  Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   335
# 102  Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    75
# 105  Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   295
# 104  Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   132
#
#      ymin  xmax  ymax  label  confidence  x_size  y_size
# 106   103   154   137      0    0.661896     430     268
# 103    62   361    85      2    0.575133     430     268
# 102    59   111    86      2    0.481845     430     268
# 105   101   347   142      0    0.653117     430     268
# 104    22   303    89      1    0.755082     430     268

# %%
data3.count()
# Out:
# image         55
# image_path    55
# xmin          55
# ymin          55
# xmax          55
# ymax          55
# label         55
# confidence    55
# x_size        55
# y_size        55
# dtype: int64

# %%
C=data3['confidence'].mean()
C
# Out:
# 0.6407022904266011

# %% [markdown]
# ## Average confidence score of 0: Light

# %%
data3_0=data3[data3['label'] == 0]
data3_0
# Out:
#             image                                         image_path  xmin  \
# 106   Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   101
# 105   Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   295
# 130  Unseen10.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   103
# 85    Unseen2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   444
# 93    Unseen3.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   360
# 92    Unseen3.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   857
# 97    Unseen4.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   600
# 101   Unseen5.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   150
# 100   Unseen5.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   547
# 112   Unseen6.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   150
# 134   Unseen7.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   182
# ...

# %%
c1=data3_0['confidence'].mean()
c1
# Out:
# 0.5116626535143171

# %% [markdown]
# ## Average confidence score of 1: Glass

# %%
data3_1=data3[data3['label'] == 1]
data3_1
# Out:
#             image                                         image_path  xmin  \
# 104   Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   132
# 129  Unseen10.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   103
# 84    Unseen2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   417
# 91    Unseen3.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   243
# 99    Unseen5.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   144
# 111   Unseen6.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    85
# 133   Unseen7.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    72
# 115   Unseen8.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    28
# 124   Unseen9.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   146
#
#      ymin  xmax  ymax  label  confidence  x_size  y_size
# 104    22   303    89      1    0.755082     430     268
# 129    37   230    85      1    0.748476     285     177
# ...

# %%
c2=data3_1['confidence'].mean()
c2
# Out:
# 0.7168299920029111

# %% [markdown]
# ## Average confidence score of 2: SideGlass

# %%
data3_2=data3[data3['label'] == 2]
data3_2
# Out:
#            image                                         image_path  xmin  \
# 103  Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   335
# 102  Unseen1.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    75
# 83   Unseen2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   310
# 89   Unseen3.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   191
# 90   Unseen3.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   222
# 98   Unseen5.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   626
# 123  Unseen9.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   309
#
#      ymin  xmax  ymax  label  confidence  x_size  y_size
# 103    62   361    85      2    0.575133     430     268
# 102    59   111    86      2    0.481845     430     268
# 83    227   365   296      2    0.532870    1200     675
# 89    435   323   547      2    0.345045    1024    1024
# 90    450   292   522      2    0.443695    1024    1024
# ...

# %%
c3=data3_2['confidence'].mean()
c3
# Out:
# 0.4905444553920201

# %% [markdown]
# ## Average confidence score of 3: Door

# %%
data3_3=data3[data3['label'] == 3]
data3_3
# Out:
#             image                                         image_path  xmin  \
# 128  Unseen10.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    57
# 82    Unseen2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   286
# 88    Unseen3.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   158
# 96    Unseen4.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   270
# 109   Unseen6.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    56
# 110   Unseen6.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    67
# 122   Unseen9.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   388
# 121   Unseen9.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   299
#
#      ymin  xmax  ymax  label  confidence  x_size  y_size
# 128    22    92   177      3    0.256544     285     177
# 82    225   389   414      3    0.578108    1200     675
# 88    446   288   682      3    0.447672    1024    1024
# 96    130   510   392      3    0.416609     750     450
# ...

# %%
c4=data3_3['confidence'].mean()
c4
# Out:
# 0.5862937048077583

# %% [markdown]
# ## Average confidence score of 4: Wheel

# %%
data3_4=data3[data3['label'] == 4]
data3_4
# Out:
#             image                                         image_path  xmin  \
# 127  Unseen10.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    37
# 126  Unseen10.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   103
# 80    Unseen2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   242
# 81    Unseen2.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   358
# 87    Unseen3.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   261
# 86    Unseen3.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    89
# 94    Unseen4.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   498
# 95    Unseen4.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    71
# 108   Unseen6.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...   118
# 107   Unseen6.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    31
# 132   Unseen7.jpg  /content/drive/MyDrive/CarPartsDetectionChalle...    43
# ...

# %%
c5=data3_4['confidence'].mean()
c5
# Out:
# 0.7941010629429537

# %% [markdown]
# ## Create a Confidence score  table

# %%
confidence_table = {'Label_Index': [0,1,2,3,4,''],
                    'Label':['Light','Glass','SideGlass','Door','Wheel','Average_confidence_score'],
                    'confidence_score_in_Phase1':[a1,a2,a3,a4,a5,A],
                    'confidence_score_in_Phase2':[b1,b2,b3,b4,b5,B],
                    'confidence_score_in_Phase3':[c1,c2,c3,c4,c5,C],
                   }

confidence_table = pd.DataFrame(confidence_table, columns = ['Label_Index', 'Label','confidence_score_in_Phase1',
                                                            'confidence_score_in_Phase2','confidence_score_in_Phase3'])

print(confidence_table)
# Out:
#   Label_Index                     Label  confidence_score_in_Phase1  \
# 0           0                     Light                    0.591444
# 1           1                     Glass                    0.745640
# 2           2                 SideGlass                    0.490936
# 3           3                      Door                    0.638261
# 4           4                     Wheel                    0.746288
# 5              Average_confidence_score                    0.660311
#
#    confidence_score_in_Phase2  confidence_score_in_Phase3
# 0                    0.618585                    0.511663
# 1                    0.872962                    0.716830
# 2                    0.506028                    0.490544
# 3                    0.667751                    0.586294
# 4                    0.925647                    0.794101
# 5                    0.669127                    0.640702

# %%
confidence_table
# Out:
#   Label_Index                     Label  confidence_score_in_Phase1  \
# 0           0                     Light                    0.591444
# 1           1                     Glass                    0.745640
# 2           2                 SideGlass                    0.490936
# 3           3                      Door                    0.638261
# 4           4                     Wheel                    0.746288
# 5              Average_confidence_score                    0.660311
#
#    confidence_score_in_Phase2  confidence_score_in_Phase3
# 0                    0.618585                    0.511663
# 1                    0.872962                    0.716830
# 2                    0.506028                    0.490544
# 3                    0.667751                    0.586294
# 4                    0.925647                    0.794101
# 5                    0.669127                    0.640702
